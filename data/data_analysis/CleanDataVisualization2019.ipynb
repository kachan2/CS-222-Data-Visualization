# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/jash_fa_19_cleaned.csv', sep=',')
df
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   35.0
# 1      2584  10002   New York       NY   New York              New York   90.0
# 2      2585  10003   New York       NY   New York              New York   45.0
# 3      2586  10004   New York       NY   New York              New York   42.0
# 4      2587  10005   New York       NY   New York              New York   21.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 5117  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 5118  33760  99801     Juneau       AK     Alaska                Juneau    1.0
# 5119  33762  99824    Douglas       AK     Alaska                Juneau    1.0
# 5120  33785  99929   Wrangell       AK     Alaska              Wrangell    1.0
# 5121  33787  13024     Auburn       NY   New York                Cayuga    1.0
#
# [5122 rows x 7 columns]

# %%
ax1 = plt.scatter(df["zip"], df["Total"],)
df092 = df.loc[(df['zip'] > 50000) &  (df['zip'] < 70000)]
ax2 = plt.scatter(df092["zip"], df092["Total"],)

# %%
states = df['state_name']
df2 = df.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1ff92d5e50>,
#   <matplotlib.patches.Wedge at 0x7f1ff92e41d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff92e4810>,
#   <matplotlib.patches.Wedge at 0x7f1ff92e4dd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff92ef750>,
#   <matplotlib.patches.Wedge at 0x7f1ff92efd90>,
#   <matplotlib.patches.Wedge at 0x7f1ff92fa110>,
#   <matplotlib.patches.Wedge at 0x7f1ff92fa690>,
#   <matplotlib.patches.Wedge at 0x7f1ff92ef410>,
#   <matplotlib.patches.Wedge at 0x7f1ff92fad10>,
#   <matplotlib.patches.Wedge at 0x7f1ff92d5e10>,
#   <matplotlib.patches.Wedge at 0x7f1ff9306c50>,
#   <matplotlib.patches.Wedge at 0x7f1ff9292290>,
#   <matplotlib.patches.Wedge at 0x7f1ff9292810>,
#   <matplotlib.patches.Wedge at 0x7f1ff9292dd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff929e410>,
#   <matplotlib.patches.Wedge at 0x7f1ff929e990>,
#   <matplotlib.patches.Wedge at 0x7f1ff929ef50>,
#   <matplotlib.patches.Wedge at 0x7f1ff92aa550>,
#   <matplotlib.patches.Wedge at 0x7f1ff92aab10>,
#   <matplotlib.patches.Wedge at 0x7f1ff92b5150>,
#   <matplotlib.patches.Wedge at 0x7f1ff92b56d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff92b5c90>,
#   <matplotlib.patches.Wedge at 0x7f1ff92c02d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff92c0850>,
#   <matplotlib.patches.Wedge at 0x7f1ff92c0e10>,
#   <matplotlib.patches.Wedge at 0x7f1ff924c450>,
#   <matplotlib.patches.Wedge at 0x7f1ff924c9d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff924cf90>,
#   <matplotlib.patches.Wedge at 0x7f1ff925a590>,
#   <matplotlib.patches.Wedge at 0x7f1ff925ab50>,
#   <matplotlib.patches.Wedge at 0x7f1ff9263190>,
#   <matplotlib.patches.Wedge at 0x7f1ff9263710>,
#   <matplotlib.patches.Wedge at 0x7f1ff9263cd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff9270310>,
#   <matplotlib.patches.Wedge at 0x7f1ff9270890>,
#   <matplotlib.patches.Wedge at 0x7f1ff9270e50>,
#   <matplotlib.patches.Wedge at 0x7f1ff927c490>,
#   <matplotlib.patches.Wedge at 0x7f1ff927ca10>,
#   <matplotlib.patches.Wedge at 0x7f1ff927cad0>,
#   <matplotlib.patches.Wedge at 0x7f1ff92875d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff9287b90>,
#   <matplotlib.patches.Wedge at 0x7f1ff92131d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff9213750>],
#  [Text(1.0999894674420387, 0.004813680149362547, 'Alabama'),
#   Text(1.0999497921834196, 0.010509741940315806, 'Alaska'),
#   Text(1.0997851395498761, 0.021740442158794466, 'Arizona'),
#   Text(1.0994464279946423, 0.034893437346041514, 'Arkansas'),
#   Text(1.079932021312734, 0.20915742717721694, 'California'),
#   Text(1.0293427763093634, 0.38788329283398126, 'Colorado'),
#   Text(1.0240741424087858, 0.4015870401914262, 'Delaware'),
#   Text(1.0155367928300327, 0.42271151203686336, 'District of Columbia'),
#   Text(0.9955610329928016, 0.4678228613335457, 'Florida'),
#   Text(0.9675416878432623, 0.5233192928656571, 'Georgia'),
#   Text(0.9500098360567165, 0.5545099741172298, 'Hawaii'),
#   Text(0.9484693530271823, 0.5571408137699109, 'Idaho'),
#   Text(-1.0764040444936283, 0.226614944338981, 'Illinois'),
#   Text(0.6572391514262232, -0.8820638853464857, 'Indiana'),
#   Text(0.689836854903927, -0.8568110139442996, 'Iowa'),
#   Text(0.7109920780855684, -0.839339183464924, 'Kansas'),
#   Text(0.728945227069717, -0.823795396887042, 'Kentucky'),
#   Text(0.7522553183715635, -0.8025658452623673, 'Louisiana'),
#   Text(0.7791495499018053, -0.7764830834524435, 'Maryland'),
#   Text(0.8152331768690848, -0.7385085424908366, 'Michigan'),
#   Text(0.8472720467242415, -0.7015198349581536, 'Minnesota'),
#   Text(0.8615702919848995, -0.6838834929789248, 'Mississippi'),
#   Text(0.8755014937926543, -0.6659558051153477, 'Missouri'),
#   Text(0.8888234426082958, -0.6480685826900866, 'Montana'),
#   Text(0.8919327374968298, -0.6437825656084604, 'Nebraska'),
#   Text(0.8958135643264848, -0.6383714106761668, 'Nevada'),
#   Text(0.8987836007992943, -0.6341829696028229, 'New Mexico'),
#   Text(0.948388122366871, -0.557279076723181, 'New York'),
#   Text(0.9968877462405176, -0.4649890551351738, 'North Carolina'),
#   Text(1.003629912375429, -0.4502521504504879, 'North Dakota'),
#   Text(1.0174684152776738, -0.4180406964786314, 'Ohio'),
#   Text(1.0317555011295039, -0.38141917346799253, 'Oklahoma'),
#   Text(1.0360283461476647, -0.3696556045544754, 'Oregon'),
#   Text(1.0471346809011453, -0.33691090818502256, 'Pennsylvania'),
#   Text(1.0560015350098284, -0.3079947370603697, 'South Carolina'),
#   Text(1.057560212585418, -0.30259939979498574, 'South Dakota'),
#   Text(1.0611884947809092, -0.28961867782418416, 'Tennessee'),
#   Text(1.0754357982569702, -0.23116626879238553, 'Texas'),
#   Text(1.085391693972697, -0.17867532189723143, 'Utah'),
#   Text(1.0921308109873502, -0.13134036581383796, 'Virginia'),
#   Text(1.0979656353306553, -0.06686900352891866, 'Washington'),
#   Text(1.099277405099655, -0.039864603815531925, 'West Virginia'),
#   Text(1.099850571336724, -0.018130657193883733, 'Wisconsin'),
#   Text(1.099999505655733, -0.001042860078521346, 'Wyoming')])

# %%
dfNoIllinois = df[df["state_name"] != 'Illinois']
dfNoIllinois
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   35.0
# 1      2584  10002   New York       NY   New York              New York   90.0
# 2      2585  10003   New York       NY   New York              New York   45.0
# 3      2586  10004   New York       NY   New York              New York   42.0
# 4      2587  10005   New York       NY   New York              New York   21.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 5117  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 5118  33760  99801     Juneau       AK     Alaska                Juneau    1.0
# 5119  33762  99824    Douglas       AK     Alaska                Juneau    1.0
# 5120  33785  99929   Wrangell       AK     Alaska              Wrangell    1.0
# 5121  33787  13024     Auburn       NY   New York                Cayuga    1.0
#
# [4135 rows x 7 columns]

# %%
ax1 = plt.scatter(dfNoIllinois["zip"], dfNoIllinois["Total"])

# %%
states = dfNoIllinois['state_name']
df2 = dfNoIllinois.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1ff8fe5450>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fe5790>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fe5dd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ff0410>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ff0d10>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ffc390>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ffc690>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ffcc50>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ff0990>,
#   <matplotlib.patches.Wedge at 0x7f1ff8ffc050>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fe5410>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f95290>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f95810>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f95dd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f9f410>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f9f990>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f9ff50>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fac550>,
#   <matplotlib.patches.Wedge at 0x7f1ff8facb10>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fb7150>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fb76d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fb7c90>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fc42d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fc4850>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fc4e10>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f4e450>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f4e9d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f4ef90>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fb2590>,
#   <matplotlib.patches.Wedge at 0x7f1ff8fb2b50>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f63190>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f63710>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f63cd0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f71310>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f71890>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f71e50>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f7b490>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f7ba10>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f7bad0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f885d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f88b90>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f121d0>,
#   <matplotlib.patches.Wedge at 0x7f1ff8f12750>],
#  [Text(1.0998101335067638, 0.020436982062785186, 'Alabama'),
#   Text(1.0990950150500196, 0.04461107364990588, 'Alaska'),
#   Text(1.09612883196334, 0.09220403320183067, 'Arizona'),
#   Text(1.0900349372427962, 0.14772892604393162, 'Arkansas'),
#   Text(0.7566442015560023, 0.798429428472974, 'California'),
#   Text(0.044781247343705526, 1.099088094688657, 'Colorado'),
#   Text(-0.017542015722608554, 1.0998601173260116, 'Delaware'),
#   Text(-0.11407789220142275, 1.0940686607845418, 'District of Columbia'),
#   Text(-0.3191196027085631, 1.0526930602825921, 'Florida'),
#   Text(-0.5601947641388869, 0.9466688049319979, 'Georgia'),
#   Text(-0.6851918196141695, 0.8605301681718216, 'Hawaii'),
#   Text(-0.695270370184005, 0.8524078321696704, 'Idaho'),
#   Text(-0.7593595534223805, 0.7958473902867076, 'Indiana'),
#   Text(-0.8759013760358751, 0.6654297704930705, 'Iowa'),
#   Text(-0.9413356820198834, 0.5691108273053337, 'Kansas'),
#   Text(-0.9894767733659807, 0.48055771242302203, 'Kentucky'),
#   Text(-1.0404978901984672, 0.35688112935897653, 'Louisiana'),
#   Text(-1.0810673659439491, 0.2032076531310065, 'Maryland'),
#   Text(-1.0998518503097814, -0.018052904756581802, 'Michigan'),
#   Text(-1.0768974800605242, -0.22425837206065072, 'Minnesota'),
#   Text(-1.0531367326352628, -0.3176523608826534, 'Mississippi'),
#   Text(-1.0212929342614125, -0.40860829950909505, 'Missouri'),
#   Text(-0.9823779580184688, -0.4949076152166824, 'Montana'),
#   Text(-0.9720584905788461, -0.5148808511622623, 'Nebraska'),
#   Text(-0.9585051429160903, -0.5396924040630973, 'Nevada'),
#   Text(-0.9476215392677738, -0.5585816129410055, 'New Mexico'),
#   Text(-0.6957981482903589, -0.8519770752993933, 'New York'),
#   Text(-0.3063831563077481, -1.056470236935666, 'North Carolina'),
#   Text(-0.23974147866922568, -1.0735567164363014, 'North Dakota'),
#   Text(-0.09271318258248062, -1.0960858843062562, 'Ohio'),
#   Text(0.07403231072085555, -1.0975059074872129, 'Oklahoma'),
#   Text(0.12694404800610432, -1.09265054279757, 'Oregon'),
#   Text(0.2712156738446037, -1.0660403642738008, 'Pennsylvania'),
#   Text(0.3935421330859479, -1.0271925766311603, 'South Carolina'),
#   Text(0.415714216887218, -1.0184211750930197, 'South Dakota'),
#   Text(0.4681106275713108, -0.9954257583339873, 'Tennessee'),
#   Text(0.6846587156003134, -0.8609543792516124, 'Texas'),
#   Text(0.8464561450314546, -0.7025040886275961, 'Utah'),
#   Text(0.9610016906457072, -0.5352342950298428, 'Virginia'),
#   Text(1.0635182957560698, -0.28094276034826965, 'Washington'),
#   Text(1.0869978951385837, -0.16862851468327905, 'West Virginia'),
#   Text(1.0973072384087328, -0.07692089791337874, 'Wisconsin'),
#   Text(1.0999910865929312, -0.004428252036936106, 'Wyoming')])
