# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/jash_fa_13_cleaned.csv', sep=',')
df
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   20.0
# 1      2584  10002   New York       NY   New York              New York   88.0
# 2      2585  10003   New York       NY   New York              New York   33.0
# 3      2586  10004   New York       NY   New York              New York   25.0
# 4      2587  10005   New York       NY   New York              New York   25.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 4267  33593  99587   Girdwood       AK     Alaska             Anchorage    1.0
# 4268  33635  99645     Palmer       AK     Alaska     Matanuska-Susitna    1.0
# 4269  33658  99669   Soldotna       AK     Alaska       Kenai Peninsula    1.0
# 4270  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 4271  33691  99712  Fairbanks       AK     Alaska  Fairbanks North Star    2.0
#
# [4272 rows x 7 columns]

# %%
ax1 = plt.scatter(df["zip"], df["Total"],)
df092 = df.loc[(df['zip'] > 50000) &  (df['zip'] < 70000)]
ax2 = plt.scatter(df092["zip"], df092["Total"],)

# %%
states = df['state_name']
df2 = df.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fac72232250>,
#   <matplotlib.patches.Wedge at 0x7fac72232690>,
#   <matplotlib.patches.Wedge at 0x7fac72232650>,
#   <matplotlib.patches.Wedge at 0x7fac7223f250>,
#   <matplotlib.patches.Wedge at 0x7fac7223fbd0>,
#   <matplotlib.patches.Wedge at 0x7fac72248250>,
#   <matplotlib.patches.Wedge at 0x7fac72248510>,
#   <matplotlib.patches.Wedge at 0x7fac722485d0>,
#   <matplotlib.patches.Wedge at 0x7fac7223f310>,
#   <matplotlib.patches.Wedge at 0x7fac7223ff50>,
#   <matplotlib.patches.Wedge at 0x7fac72232210>,
#   <matplotlib.patches.Wedge at 0x7fac7225f0d0>,
#   <matplotlib.patches.Wedge at 0x7fac7225f190>,
#   <matplotlib.patches.Wedge at 0x7fac7225f750>,
#   <matplotlib.patches.Wedge at 0x7fac721ed250>,
#   <matplotlib.patches.Wedge at 0x7fac721ed310>,
#   <matplotlib.patches.Wedge at 0x7fac721ed8d0>,
#   <matplotlib.patches.Wedge at 0x7fac721f73d0>,
#   <matplotlib.patches.Wedge at 0x7fac721f7490>,
#   <matplotlib.patches.Wedge at 0x7fac721f7a50>,
#   <matplotlib.patches.Wedge at 0x7fac72202050>,
#   <matplotlib.patches.Wedge at 0x7fac72202610>,
#   <matplotlib.patches.Wedge at 0x7fac7220e110>,
#   <matplotlib.patches.Wedge at 0x7fac7220e1d0>,
#   <matplotlib.patches.Wedge at 0x7fac7220e790>,
#   <matplotlib.patches.Wedge at 0x7fac7221b290>,
#   <matplotlib.patches.Wedge at 0x7fac7221b350>,
#   <matplotlib.patches.Wedge at 0x7fac7221b910>,
#   <matplotlib.patches.Wedge at 0x7fac721a7410>,
#   <matplotlib.patches.Wedge at 0x7fac721a74d0>,
#   <matplotlib.patches.Wedge at 0x7fac721a7a90>,
#   <matplotlib.patches.Wedge at 0x7fac721b3090>,
#   <matplotlib.patches.Wedge at 0x7fac721b3650>,
#   <matplotlib.patches.Wedge at 0x7fac721be150>,
#   <matplotlib.patches.Wedge at 0x7fac721be210>,
#   <matplotlib.patches.Wedge at 0x7fac721be7d0>,
#   <matplotlib.patches.Wedge at 0x7fac721ca2d0>,
#   <matplotlib.patches.Wedge at 0x7fac721ca390>,
#   <matplotlib.patches.Wedge at 0x7fac721ca950>,
#   <matplotlib.patches.Wedge at 0x7fac721d6450>,
#   <matplotlib.patches.Wedge at 0x7fac721d6510>,
#   <matplotlib.patches.Wedge at 0x7fac721d6ad0>,
#   <matplotlib.patches.Wedge at 0x7fac721e00d0>,
#   <matplotlib.patches.Wedge at 0x7fac721e0690>,
#   <matplotlib.patches.Wedge at 0x7fac7216c190>],
#  [Text(1.0999943345191097, 0.0035304427288141084, 'Alabama'),
#   Text(1.0999723161360047, 0.007804084468658538, 'Alaska'),
#   Text(1.0999105422518831, 0.014028508230328978, 'Arizona'),
#   Text(1.099774016065726, 0.022296044193196512, 'Arkansas'),
#   Text(1.0952387650619213, 0.10223525568822849, 'California'),
#   Text(1.0839979183134294, 0.1869452141461548, 'Colorado'),
#   Text(1.0823803248702892, 0.19609393752405357, 'Delaware'),
#   Text(1.078931723145548, 0.2142576411477052, 'District of Columbia'),
#   Text(1.0709729889983512, 0.2510315853352672, 'Florida'),
#   Text(1.0609066913815037, 0.2906492597306088, 'Georgia'),
#   Text(1.0551920775748114, 0.3107566241021318, 'Guam'),
#   Text(1.0545864138311591, 0.3128058435559273, 'Hawaii'),
#   Text(1.0537637881452644, 0.3155659658355798, 'Idaho'),
#   Text(-1.0705046706007542, 0.2530212446060034, 'Illinois'),
#   Text(0.8121581805412809, -0.7418888661921516, 'Indiana'),
#   Text(0.8378988559750856, -0.7126889273418263, 'Iowa'),
#   Text(0.8555694061843232, -0.6913761575303308, 'Kansas'),
#   Text(0.8695779556451212, -0.6736721599235431, 'Kentucky'),
#   Text(0.8843818033684944, -0.6541168289156685, 'Louisiana'),
#   Text(0.9001365686570195, -0.6322611468106886, 'Maryland'),
#   Text(0.9236625982182278, -0.5973670602341183, 'Michigan'),
#   Text(0.9441723856595301, -0.564392156357609, 'Minnesota'),
#   Text(0.9527362250586237, -0.5498124093370791, 'Mississippi'),
#   Text(0.9661381359144328, -0.525905982407298, 'Missouri'),
#   Text(0.9786011038816244, -0.5023344299186215, 'Montana'),
#   Text(0.9803347570306843, -0.4989426461604474, 'Nebraska'),
#   Text(0.982433056389751, -0.4947982313152429, 'Nevada'),
#   Text(0.9838914433514085, -0.49189188619033153, 'New Mexico'),
#   Text(1.0163562789293326, -0.42073734595459994, 'New York'),
#   Text(1.045978218299045, -0.3404843121847989, 'North Carolina'),
#   Text(1.0490404670140712, -0.33092914432986964, 'North Dakota'),
#   Text(1.0582113185333422, -0.30031451068492454, 'Ohio'),
#   Text(1.067190762916358, -0.2666530996369665, 'Oklahoma'),
#   Text(1.0694265930045033, -0.25753982638570794, 'Oregon'),
#   Text(1.0752567370797488, -0.2319977356885456, 'Pennsylvania'),
#   Text(1.0799506723132382, -0.2090611043933925, 'South Carolina'),
#   Text(1.0808929366006177, -0.20413343578868473, 'South Dakota'),
#   Text(1.0827591820937794, -0.19399111730079288, 'Tennessee'),
#   Text(1.0882512389412964, -0.16034101453693497, 'Texas'),
#   Text(1.092087059639998, -0.13170366041558304, 'Utah'),
#   Text(1.0956607240270053, -0.09760931218187391, 'Virginia'),
#   Text(1.0986112780812152, -0.05525630889553827, 'Washington'),
#   Text(1.0992576590014123, -0.04040543437132066, 'West Virginia'),
#   Text(1.0998430620571522, -0.018580603993073146, 'Wisconsin'),
#   Text(1.0999999646436003, -0.0002788979708038649, 'Wyoming')])

# %%
dfNoIllinois = df[df["state_name"] != 'Illinois']
dfNoIllinois
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   20.0
# 1      2584  10002   New York       NY   New York              New York   88.0
# 2      2585  10003   New York       NY   New York              New York   33.0
# 3      2586  10004   New York       NY   New York              New York   25.0
# 4      2587  10005   New York       NY   New York              New York   25.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 4267  33593  99587   Girdwood       AK     Alaska             Anchorage    1.0
# 4268  33635  99645     Palmer       AK     Alaska     Matanuska-Susitna    1.0
# 4269  33658  99669   Soldotna       AK     Alaska       Kenai Peninsula    1.0
# 4270  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 4271  33691  99712  Fairbanks       AK     Alaska  Fairbanks North Star    2.0
#
# [3262 rows x 7 columns]

# %%
ax1 = plt.scatter(dfNoIllinois["zip"], dfNoIllinois["Total"])

# %%
states = dfNoIllinois['state_name']
df2 = dfNoIllinois.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fac720ae310>,
#   <matplotlib.patches.Wedge at 0x7fac720ae710>,
#   <matplotlib.patches.Wedge at 0x7fac720ae6d0>,
#   <matplotlib.patches.Wedge at 0x7fac720b92d0>,
#   <matplotlib.patches.Wedge at 0x7fac720b9c50>,
#   <matplotlib.patches.Wedge at 0x7fac720c42d0>,
#   <matplotlib.patches.Wedge at 0x7fac720c4590>,
#   <matplotlib.patches.Wedge at 0x7fac720c4650>,
#   <matplotlib.patches.Wedge at 0x7fac720b9390>,
#   <matplotlib.patches.Wedge at 0x7fac720b9fd0>,
#   <matplotlib.patches.Wedge at 0x7fac720ae2d0>,
#   <matplotlib.patches.Wedge at 0x7fac720db150>,
#   <matplotlib.patches.Wedge at 0x7fac720db210>,
#   <matplotlib.patches.Wedge at 0x7fac720db7d0>,
#   <matplotlib.patches.Wedge at 0x7fac720672d0>,
#   <matplotlib.patches.Wedge at 0x7fac72067390>,
#   <matplotlib.patches.Wedge at 0x7fac72067950>,
#   <matplotlib.patches.Wedge at 0x7fac72072450>,
#   <matplotlib.patches.Wedge at 0x7fac72072510>,
#   <matplotlib.patches.Wedge at 0x7fac72072ad0>,
#   <matplotlib.patches.Wedge at 0x7fac7207e0d0>,
#   <matplotlib.patches.Wedge at 0x7fac7207e690>,
#   <matplotlib.patches.Wedge at 0x7fac7208a190>,
#   <matplotlib.patches.Wedge at 0x7fac7208a250>,
#   <matplotlib.patches.Wedge at 0x7fac7208a810>,
#   <matplotlib.patches.Wedge at 0x7fac72095310>,
#   <matplotlib.patches.Wedge at 0x7fac720953d0>,
#   <matplotlib.patches.Wedge at 0x7fac72095990>,
#   <matplotlib.patches.Wedge at 0x7fac72022490>,
#   <matplotlib.patches.Wedge at 0x7fac72022550>,
#   <matplotlib.patches.Wedge at 0x7fac7202d050>,
#   <matplotlib.patches.Wedge at 0x7fac7202d110>,
#   <matplotlib.patches.Wedge at 0x7fac7202d6d0>,
#   <matplotlib.patches.Wedge at 0x7fac720381d0>,
#   <matplotlib.patches.Wedge at 0x7fac72038290>,
#   <matplotlib.patches.Wedge at 0x7fac72038850>,
#   <matplotlib.patches.Wedge at 0x7fac72044350>,
#   <matplotlib.patches.Wedge at 0x7fac72044410>,
#   <matplotlib.patches.Wedge at 0x7fac720449d0>,
#   <matplotlib.patches.Wedge at 0x7fac7204f4d0>,
#   <matplotlib.patches.Wedge at 0x7fac7204f590>,
#   <matplotlib.patches.Wedge at 0x7fac7205b090>,
#   <matplotlib.patches.Wedge at 0x7fac7205b150>,
#   <matplotlib.patches.Wedge at 0x7fac7205b710>],
#  [Text(1.0997963555298222, 0.02116545211709411, 'Alabama'),
#   Text(1.0990050255723596, 0.04677556805317863, 'Alaska'),
#   Text(1.0967858870751144, 0.08402807812186866, 'Arizona'),
#   Text(1.0918865282980312, 0.13335594970331308, 'Arkansas'),
#   Text(0.9331283074035421, 0.582470224064888, 'California'),
#   Text(0.572038914166061, 0.9395591948779566, 'Colorado'),
#   Text(0.5237484173033786, 0.9673094620503855, 'Delaware'),
#   Text(0.4237805783511494, 1.015091139461066, 'District of Columbia'),
#   Text(0.208176399417443, 1.0801215610872645, 'Florida'),
#   Text(-0.03564301216274009, 1.0994223827464888, 'Georgia'),
#   Text(-0.16040475630195022, 1.0882418454349714, 'Guam'),
#   Text(-0.17306810507646647, 1.0862998807904019, 'Hawaii'),
#   Text(-0.1900986377078169, 1.0834493564267933, 'Idaho'),
#   Text(-0.29812875271109, 1.058829186794041, 'Indiana'),
#   Text(-0.5144175385512308, 0.9723037570794906, 'Iowa'),
#   Text(-0.6547378049540498, 0.8839221723454803, 'Kansas'),
#   Text(-0.7582802340491764, 0.7968758288782051, 'Kentucky'),
#   Text(-0.8577276198056693, 0.6886968347702069, 'Louisiana'),
#   Text(-0.9492682425598943, 0.5557785563218951, 'Maryland'),
#   Text(-1.0507776379839928, 0.3253711042990469, 'Michigan'),
#   Text(-1.0956837073983672, 0.09735098017878205, 'Minnesota'),
#   Text(-1.099993089485593, -0.0038991132249213147, 'Mississippi'),
#   Text(-1.087162334346204, -0.16756508818638954, 'Missouri'),
#   Text(-1.0514345440518105, -0.3232420139377947, 'Montana'),
#   Text(-1.044497387357285, -0.3450003011648049, 'Nebraska'),
#   Text(-1.035428454391336, -0.3713326215628912, 'Nevada'),
#   Text(-1.028684917489551, -0.3896246148917135, 'New Mexico'),
#   Text(-0.7754506594284472, -0.7801770791249808, 'New York'),
#   Text(-0.34182528320581906, -1.045540757580144, 'North Carolina'),
#   Text(-0.2841629007014186, -1.062662432696741, 'North Dakota'),
#   Text(-0.09568638012016215, -1.0958303320585263, 'Ohio'),
#   Text(0.11287598291579248, -1.0941933158636978, 'Oklahoma'),
#   Text(0.16866602773468617, -1.0869920749886828, 'Oregon'),
#   Text(0.32164435044625667, -1.0519243850325013, 'Pennsylvania'),
#   Text(0.45289927428754606, -1.0024381513838219, 'South Carolina'),
#   Text(0.48013783327309856, -0.9896805853707621, 'South Dakota'),
#   Text(0.5349786183460112, -0.9611440463908586, 'Tennessee'),
#   Text(0.7033614550505545, -0.8457438522089102, 'Texas'),
#   Text(0.8272991475025497, -0.7249662892449239, 'Utah'),
#   Text(0.9475752379209275, -0.5586601547265546, 'Virginia'),
#   Text(1.0504475679941168, -0.32643514960133463, 'Washington'),
#   Text(1.073420869774452, -0.240348988624165, 'West Virginia'),
#   Text(1.0943635207865123, -0.11121368787945438, 'Wisconsin'),
#   Text(1.0999987306591843, -0.0016710919135007134, 'Wyoming')])
