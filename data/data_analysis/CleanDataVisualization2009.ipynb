# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/jash_fa_09_cleaned.csv', sep=',')
df
# Out:
#       index    zip          city state_id   state_name           county_name  \
# 0         1    602        Aguada       PR  Puerto Rico                Aguada
# 1         4    610        Anasco       PR  Puerto Rico                Añasco
# 2        28    667         Lajas       PR  Puerto Rico                 Lajas
# 3        46    703  Aguas Buenas       PR  Puerto Rico          Aguas Buenas
# 4        58    725        Caguas       PR  Puerto Rico                Caguas
# ...     ...    ...           ...      ...          ...                   ...
# 3971  33585  99577   Eagle River       AK       Alaska             Anchorage
# 3972  33635  99645        Palmer       AK       Alaska     Matanuska-Susitna
# 3973  33674  99686        Valdez       AK       Alaska               Chugach
# 3974  33684  99702   Eielson Afb       AK       Alaska  Fairbanks North Star
# 3975  33762  99824       Douglas       AK       Alaska                Juneau
#
#       Total
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       2.0
# ...     ...
# 3971    1.0
# 3972    1.0
# 3973    1.0
# 3974    1.0
# 3975    1.0
#
# [3976 rows x 7 columns]

# %%
ax1 = plt.scatter(df["zip"], df["Total"],)
df092 = df.loc[(df['zip'] > 50000) &  (df['zip'] < 70000)]
ax2 = plt.scatter(df092["zip"], df092["Total"],)

# %%
states = df['state_name']
df2 = df.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f14885fad10>,
#   <matplotlib.patches.Wedge at 0x7f1488607110>,
#   <matplotlib.patches.Wedge at 0x7f1488607750>,
#   <matplotlib.patches.Wedge at 0x7f1488607d10>,
#   <matplotlib.patches.Wedge at 0x7f1488610650>,
#   <matplotlib.patches.Wedge at 0x7f1488610c90>,
#   <matplotlib.patches.Wedge at 0x7f1488610fd0>,
#   <matplotlib.patches.Wedge at 0x7f148859a5d0>,
#   <matplotlib.patches.Wedge at 0x7f1488607dd0>,
#   <matplotlib.patches.Wedge at 0x7f148859abd0>,
#   <matplotlib.patches.Wedge at 0x7f14885facd0>,
#   <matplotlib.patches.Wedge at 0x7f14885a7b90>,
#   <matplotlib.patches.Wedge at 0x7f14885a7c50>,
#   <matplotlib.patches.Wedge at 0x7f14885b4750>,
#   <matplotlib.patches.Wedge at 0x7f14885b4d10>,
#   <matplotlib.patches.Wedge at 0x7f14885b4dd0>,
#   <matplotlib.patches.Wedge at 0x7f14885bf8d0>,
#   <matplotlib.patches.Wedge at 0x7f14885bfe90>,
#   <matplotlib.patches.Wedge at 0x7f14885bff50>,
#   <matplotlib.patches.Wedge at 0x7f14885cba50>,
#   <matplotlib.patches.Wedge at 0x7f14885cbb10>,
#   <matplotlib.patches.Wedge at 0x7f1488559610>,
#   <matplotlib.patches.Wedge at 0x7f1488559bd0>,
#   <matplotlib.patches.Wedge at 0x7f1488559c90>,
#   <matplotlib.patches.Wedge at 0x7f1488565790>,
#   <matplotlib.patches.Wedge at 0x7f1488565d50>,
#   <matplotlib.patches.Wedge at 0x7f1488565e10>,
#   <matplotlib.patches.Wedge at 0x7f148856f910>,
#   <matplotlib.patches.Wedge at 0x7f148856fed0>,
#   <matplotlib.patches.Wedge at 0x7f148856ff90>,
#   <matplotlib.patches.Wedge at 0x7f1488579a90>,
#   <matplotlib.patches.Wedge at 0x7f1488579b50>,
#   <matplotlib.patches.Wedge at 0x7f1488585650>,
#   <matplotlib.patches.Wedge at 0x7f14887e26d0>,
#   <matplotlib.patches.Wedge at 0x7f14887d8fd0>,
#   <matplotlib.patches.Wedge at 0x7f1488585d50>,
#   <matplotlib.patches.Wedge at 0x7f1488592850>,
#   <matplotlib.patches.Wedge at 0x7f1488592e10>,
#   <matplotlib.patches.Wedge at 0x7f1488592ed0>,
#   <matplotlib.patches.Wedge at 0x7f148851d9d0>,
#   <matplotlib.patches.Wedge at 0x7f148851df90>,
#   <matplotlib.patches.Wedge at 0x7f1488527590>,
#   <matplotlib.patches.Wedge at 0x7f1488527b50>,
#   <matplotlib.patches.Wedge at 0x7f1488527c10>,
#   <matplotlib.patches.Wedge at 0x7f1488533710>,
#   <matplotlib.patches.Wedge at 0x7f1488533cd0>,
#   <matplotlib.patches.Wedge at 0x7f1488533d90>,
#   <matplotlib.patches.Wedge at 0x7f148853f890>,
#   <matplotlib.patches.Wedge at 0x7f148853fe50>,
#   <matplotlib.patches.Wedge at 0x7f148853ff10>,
#   <matplotlib.patches.Wedge at 0x7f148854aa10>,
#   <matplotlib.patches.Wedge at 0x7f148854afd0>,
#   <matplotlib.patches.Wedge at 0x7f14884d75d0>,
#   <matplotlib.patches.Wedge at 0x7f14884d7b90>],
#  [Text(1.0999972786282657, 0.00244683681713877, 'Alabama'),
#   Text(1.0999842280207925, 0.0058905097827865625, 'Alaska'),
#   Text(1.0999471371043692, 0.010784042651176221, 'Arizona'),
#   Text(1.0998694625504923, 0.01694595376162909, 'Arkansas'),
#   Text(1.0986021152949434, 0.055438184218787157, 'California'),
#   Text(1.0956888458076075, 0.09729313014182084, 'Colorado'),
#   Text(1.0945929875409282, 0.10893205050041882, 'Connecticut'),
#   Text(1.0938990181906934, 0.11569329281093724, 'Delaware'),
#   Text(1.092680952260038, 0.12668202938103196, 'District of Columbia'),
#   Text(1.0894557078309917, 0.1519416357502876, 'Florida'),
#   Text(1.085235148952365, 0.17962369408944437, 'Georgia'),
#   Text(1.0830437265163686, 0.1923961705791916, 'Guam'),
#   Text(1.0827252447570255, 0.1941804427995757, 'Hawaii'),
#   Text(1.0821445705938013, 0.1973908010378335, 'Idaho'),
#   Text(-1.076917495904587, 0.22416223369379995, 'Illinois'),
#   Text(0.9209079810603039, -0.601604928852345, 'Indiana'),
#   Text(0.9360658230224218, -0.577737635064011, 'Iowa'),
#   Text(0.945735531219048, -0.5617689071048925, 'Kansas'),
#   Text(0.9536910517553542, -0.5481545200048674, 'Kentucky'),
#   Text(0.9612744315957871, -0.534744300727176, 'Louisiana'),
#   Text(0.9642986778872015, -0.5292712535411266, 'Maine'),
#   Text(0.9705949656193678, -0.5176344392661083, 'Maryland'),
#   Text(0.9812136044092952, -0.4972120900803995, 'Massachusetts'),
#   Text(0.9929287105463283, -0.4733841735554813, 'Michigan'),
#   Text(1.0046935347188914, -0.447873755978244, 'Minnesota'),
#   Text(1.0102231319733834, -0.4352576520015337, 'Mississippi'),
#   Text(1.0196202813413269, -0.41276443872677976, 'Missouri'),
#   Text(1.0282271729269603, -0.39083101316890273, 'Montana'),
#   Text(1.0295414500594628, -0.38735565390149973, 'Nebraska'),
#   Text(1.0311598874763608, -0.38302648271332257, 'Nevada'),
#   Text(1.0323539486724187, -0.3797964252865803, 'New Hampshire'),
#   Text(1.0401928578666906, -0.35776922512022624, 'New Jersey'),
#   Text(1.047451191160653, -0.33592559017754103, 'New Mexico'),
#   Text(1.0593046706518816, -0.29643484062287445, 'New York'),
#   Text(1.0709868817803347, -0.25097230734572185, 'North Carolina'),
#   Text(1.0727782421685823, -0.24320123998385965, 'North Dakota'),
#   Text(1.0729183169556162, -0.24258253263812768, 'Northern Mariana Islands'),
#   Text(1.0781024582584362, -0.21839205456498836, 'Ohio'),
#   Text(1.0833278698314717, -0.19078974408077085, 'Oklahoma'),
#   Text(1.0845315167870044, -0.1838243430443303, 'Oregon'),
#   Text(1.0875629666833833, -0.16494481955744594, 'Pennsylvania'),
#   Text(1.0901087784956482, -0.1471830528516306, 'Puerto Rico'),
#   Text(1.0906469422242713, -0.14314065605846316, 'Rhode Island'),
#   Text(1.091147182035271, -0.13927608242798684, 'South Carolina'),
#   Text(1.09158904597491, -0.13576949107802436, 'South Dakota'),
#   Text(1.0924813320628133, -0.12839213018819046, 'Tennessee'),
#   Text(1.0952198952398038, -0.10243720550128893, 'Texas'),
#   Text(1.0970775090327736, -0.08013076297181303, 'Utah'),
#   Text(1.09730400337116, -0.07696703310915304, 'Vermont'),
#   Text(1.0983346639457616, -0.06050591686067484, 'Virginia'),
#   Text(1.0993816911045264, -0.036876784894451634, 'Washington'),
#   Text(1.0996751530123892, -0.026731214846668454, 'West Virginia'),
#   Text(1.0999278765947766, -0.012596280788628383, 'Wisconsin'),
#   Text(1.0999999403151748, -0.00036236254215873725, 'Wyoming')])

# %%
dfNoIllinois = df[df["state_name"] != 'Illinois']
dfNoIllinois
# Out:
#       index    zip          city state_id   state_name           county_name  \
# 0         1    602        Aguada       PR  Puerto Rico                Aguada
# 1         4    610        Anasco       PR  Puerto Rico                Añasco
# 2        28    667         Lajas       PR  Puerto Rico                 Lajas
# 3        46    703  Aguas Buenas       PR  Puerto Rico          Aguas Buenas
# 4        58    725        Caguas       PR  Puerto Rico                Caguas
# ...     ...    ...           ...      ...          ...                   ...
# 3971  33585  99577   Eagle River       AK       Alaska             Anchorage
# 3972  33635  99645        Palmer       AK       Alaska     Matanuska-Susitna
# 3973  33674  99686        Valdez       AK       Alaska               Chugach
# 3974  33684  99702   Eielson Afb       AK       Alaska  Fairbanks North Star
# 3975  33762  99824       Douglas       AK       Alaska                Juneau
#
#       Total
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       2.0
# ...     ...
# 3971    1.0
# 3972    1.0
# 3973    1.0
# 3974    1.0
# 3975    1.0
#
# [2937 rows x 7 columns]

# %%
ax1 = plt.scatter(dfNoIllinois["zip"], dfNoIllinois["Total"])

# %%
states = dfNoIllinois['state_name']
df2 = dfNoIllinois.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f148841d5d0>,
#   <matplotlib.patches.Wedge at 0x7f148841d990>,
#   <matplotlib.patches.Wedge at 0x7f148841df90>,
#   <matplotlib.patches.Wedge at 0x7f1488429590>,
#   <matplotlib.patches.Wedge at 0x7f1488429e90>,
#   <matplotlib.patches.Wedge at 0x7f1488433510>,
#   <matplotlib.patches.Wedge at 0x7f1488433810>,
#   <matplotlib.patches.Wedge at 0x7f1488433d50>,
#   <matplotlib.patches.Wedge at 0x7f1488429b50>,
#   <matplotlib.patches.Wedge at 0x7f1488433210>,
#   <matplotlib.patches.Wedge at 0x7f148841d590>,
#   <matplotlib.patches.Wedge at 0x7f1488440c50>,
#   <matplotlib.patches.Wedge at 0x7f148844c690>,
#   <matplotlib.patches.Wedge at 0x7f148844cbd0>,
#   <matplotlib.patches.Wedge at 0x7f148844cc10>,
#   <matplotlib.patches.Wedge at 0x7f14883d9690>,
#   <matplotlib.patches.Wedge at 0x7f14883d9bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883d9c10>,
#   <matplotlib.patches.Wedge at 0x7f14883e6690>,
#   <matplotlib.patches.Wedge at 0x7f14883e6bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883e6c10>,
#   <matplotlib.patches.Wedge at 0x7f14883f2690>,
#   <matplotlib.patches.Wedge at 0x7f14883f2bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883f2c10>,
#   <matplotlib.patches.Wedge at 0x7f14883ff690>,
#   <matplotlib.patches.Wedge at 0x7f14883ffbd0>,
#   <matplotlib.patches.Wedge at 0x7f14883ffc10>,
#   <matplotlib.patches.Wedge at 0x7f148840c690>,
#   <matplotlib.patches.Wedge at 0x7f148840cbd0>,
#   <matplotlib.patches.Wedge at 0x7f148840cc10>,
#   <matplotlib.patches.Wedge at 0x7f1488397690>,
#   <matplotlib.patches.Wedge at 0x7f1488397bd0>,
#   <matplotlib.patches.Wedge at 0x7f1488397c10>,
#   <matplotlib.patches.Wedge at 0x7f14883a4690>,
#   <matplotlib.patches.Wedge at 0x7f14883a4bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883a4c10>,
#   <matplotlib.patches.Wedge at 0x7f14883b0690>,
#   <matplotlib.patches.Wedge at 0x7f14883b0bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883b0c10>,
#   <matplotlib.patches.Wedge at 0x7f14883bd690>,
#   <matplotlib.patches.Wedge at 0x7f14883bdbd0>,
#   <matplotlib.patches.Wedge at 0x7f14883bdc10>,
#   <matplotlib.patches.Wedge at 0x7f14883c9690>,
#   <matplotlib.patches.Wedge at 0x7f14883c9bd0>,
#   <matplotlib.patches.Wedge at 0x7f14883c9c10>,
#   <matplotlib.patches.Wedge at 0x7f1488357690>,
#   <matplotlib.patches.Wedge at 0x7f1488357bd0>,
#   <matplotlib.patches.Wedge at 0x7f1488357c10>,
#   <matplotlib.patches.Wedge at 0x7f1488363690>,
#   <matplotlib.patches.Wedge at 0x7f1488363bd0>,
#   <matplotlib.patches.Wedge at 0x7f1488363c10>,
#   <matplotlib.patches.Wedge at 0x7f148836f690>,
#   <matplotlib.patches.Wedge at 0x7f148836fbd0>],
#  [Text(1.0998207879072814, 0.01985533900508991, 'Alabama'),
#   Text(1.0989614917966837, 0.047787441320997895, 'Alaska'),
#   Text(1.0965205036444494, 0.08742302378277113, 'Arizona'),
#   Text(1.091414432589165, 0.1371660903287374, 'Arkansas'),
#   Text(1.0091997618187443, 0.43762522864317355, 'California'),
#   Text(0.8279222438822796, 0.72425462241185, 'Colorado'),
#   Text(0.7624590623814387, 0.7928784132465819, 'Connecticut'),
#   Text(0.721760530351544, 0.8300974261053086, 'Delaware'),
#   Text(0.6517290640838598, 0.8861428931207294, 'District of Columbia'),
#   Text(0.47476221690286075, 0.9922705464748418, 'Florida'),
#   Text(0.261132035909709, 1.068555127179525, 'Georgia'),
#   Text(0.15793590707310853, 1.0886028886866848, 'Guam'),
#   Text(0.14336616017711107, 1.0906173224903735, 'Hawaii'),
#   Text(0.11707777569880765, 1.0937517060272042, 'Idaho'),
#   Text(-0.018017031641193018, 1.0998524385438442, 'Indiana'),
#   Text(-0.24538751883310414, 1.0722802644835598, 'Iowa'),
#   Text(-0.3902769245588691, 1.028437612185042, 'Kansas'),
#   Text(-0.5070081631353571, 0.9761878520623535, 'Kentucky'),
#   Text(-0.614448128869759, 0.9123888956626184, 'Louisiana'),
#   Text(-0.6558689967094489, 0.8830831552890934, 'Maine'),
#   Text(-0.7388084912574323, 0.8149613569034526, 'Maryland'),
#   Text(-0.8659105443200893, 0.6783796350387347, 'Massachusetts'),
#   Text(-0.9813893434638372, 0.4968651291201857, 'Michigan'),
#   Text(-1.0626293578769805, 0.28428655926363544, 'Minnesota'),
#   Text(-1.0859872561418908, 0.1750190832378208, 'Mississippi'),
#   Text(-1.099778752133946, -0.022061195677046213, 'Missouri'),
#   Text(-1.0793895905381083, -0.21193893421921076, 'Montana'),
#   Text(-1.0731753268797803, -0.24144299073793102, 'Nebraska'),
#   Text(-1.0643206952675972, -0.27788749094750326, 'Nevada'),
#   Text(-1.0569181201675297, -0.304834524392391, 'New Hampshire'),
#   Text(-0.9889133322779962, -0.4817161210119812, 'New Jersey'),
#   Text(-0.8932782957516086, -0.6419142359685615, 'New Mexico'),
#   Text(-0.6599946131369127, -0.8800040401215538, 'New York'),
#   Text(-0.32210504731777817, -1.0517834085458908, 'North Carolina'),
#   Text(-0.25970298937676234, -1.0689033432957227, 'North Dakota'),
#   Text(-0.2546977348131796, -1.0701070338433607, 'Northern Mariana Islands'),
#   Text(-0.05623532464894814, -1.0985615996664126, 'Ohio'),
#   Text(0.1710245917942478, -1.08662348078882, 'Oklahoma'),
#   Text(0.22743183957375837, -1.0762317400765025, 'Oregon'),
#   Text(0.3764908905927259, -1.0335640325111437, 'Pennsylvania'),
#   Text(0.5096169464807402, -0.9748284812517772, 'Puerto Rico'),
#   Text(0.5387100862730461, -0.9590575806215639, 'Rhode Island'),
#   Text(0.5660550105749235, -0.9431764018480443, 'South Carolina'),
#   Text(0.5904522753424349, -0.9280981147179116, 'South Dakota'),
#   Text(0.6404203059540963, -0.8943499492489849, 'Tennessee'),
#   Text(0.7997277193302741, -0.7552718549865329, 'Texas'),
#   Text(0.9130046258581312, -0.6135328460332453, 'Utah'),
#   Text(0.927109925738448, -0.5920026905321037, 'Vermont'),
#   Text(0.992111793875228, -0.4750938733068206, 'Virginia'),
#   Text(1.059527591041047, -0.29563708127154104, 'Washington'),
#   Text(1.0786750824733464, -0.21554597294108688, 'West Virginia'),
#   Text(1.0952535529327527, -0.10207671031230371, 'Wisconsin'),
#   Text(1.0999960665441562, -0.00294169804443992, 'Wyoming')])
