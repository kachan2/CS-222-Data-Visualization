# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/jash_fa_15_cleaned.csv', sep=',')
df
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   37.0
# 1      2584  10002   New York       NY   New York              New York   90.0
# 2      2585  10003   New York       NY   New York              New York   42.0
# 3      2586  10004   New York       NY   New York              New York   26.0
# 4      2587  10005   New York       NY   New York              New York   27.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 4336  33658  99669   Soldotna       AK     Alaska       Kenai Peninsula    1.0
# 4337  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 4338  33691  99712  Fairbanks       AK     Alaska  Fairbanks North Star    2.0
# 4339  33760  99801     Juneau       AK     Alaska                Juneau    2.0
# 4340  33785  99929   Wrangell       AK     Alaska              Wrangell    1.0
#
# [4341 rows x 7 columns]

# %%
ax1 = plt.scatter(df["zip"], df["Total"],)
df092 = df.loc[(df['zip'] > 50000) &  (df['zip'] < 70000)]
ax2 = plt.scatter(df092["zip"], df092["Total"],)

# %%
states = df['state_name']
df2 = df.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe471ce4950>,
#   <matplotlib.patches.Wedge at 0x7fe471ce4e10>,
#   <matplotlib.patches.Wedge at 0x7fe471c70450>,
#   <matplotlib.patches.Wedge at 0x7fe471c70510>,
#   <matplotlib.patches.Wedge at 0x7fe471c7b350>,
#   <matplotlib.patches.Wedge at 0x7fe471c7b310>,
#   <matplotlib.patches.Wedge at 0x7fe471c7b710>,
#   <matplotlib.patches.Wedge at 0x7fe471c862d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c70ad0>,
#   <matplotlib.patches.Wedge at 0x7fe471c7b750>,
#   <matplotlib.patches.Wedge at 0x7fe471ce4910>,
#   <matplotlib.patches.Wedge at 0x7fe471c933d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c93950>,
#   <matplotlib.patches.Wedge at 0x7fe471c9e450>,
#   <matplotlib.patches.Wedge at 0x7fe471c9e510>,
#   <matplotlib.patches.Wedge at 0x7fe471c9ead0>,
#   <matplotlib.patches.Wedge at 0x7fe471c290d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c29690>,
#   <matplotlib.patches.Wedge at 0x7fe471c35190>,
#   <matplotlib.patches.Wedge at 0x7fe471c35250>,
#   <matplotlib.patches.Wedge at 0x7fe471c35810>,
#   <matplotlib.patches.Wedge at 0x7fe471c41310>,
#   <matplotlib.patches.Wedge at 0x7fe471c413d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c41990>,
#   <matplotlib.patches.Wedge at 0x7fe471c4e490>,
#   <matplotlib.patches.Wedge at 0x7fe471c4e550>,
#   <matplotlib.patches.Wedge at 0x7fe471c5a050>,
#   <matplotlib.patches.Wedge at 0x7fe471c5a110>,
#   <matplotlib.patches.Wedge at 0x7fe471c5a6d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c641d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c64290>,
#   <matplotlib.patches.Wedge at 0x7fe471c64850>,
#   <matplotlib.patches.Wedge at 0x7fe471bf1350>,
#   <matplotlib.patches.Wedge at 0x7fe471bf1410>,
#   <matplotlib.patches.Wedge at 0x7fe471bf19d0>,
#   <matplotlib.patches.Wedge at 0x7fe471bfc4d0>,
#   <matplotlib.patches.Wedge at 0x7fe471bfc590>,
#   <matplotlib.patches.Wedge at 0x7fe471c5b090>,
#   <matplotlib.patches.Wedge at 0x7fe471c5b150>,
#   <matplotlib.patches.Wedge at 0x7fe471c5b710>,
#   <matplotlib.patches.Wedge at 0x7fe471c12210>,
#   <matplotlib.patches.Wedge at 0x7fe471c122d0>,
#   <matplotlib.patches.Wedge at 0x7fe471c12890>,
#   <matplotlib.patches.Wedge at 0x7fe471c1d390>,
#   <matplotlib.patches.Wedge at 0x7fe471c1d450>,
#   <matplotlib.patches.Wedge at 0x7fe471c1da10>],
#  [Text(1.0999899206600774, 0.004708975072851628, 'Alabama'),
#   Text(1.0999522541950582, 0.010248828772611794, 'Alaska'),
#   Text(1.0998449962567152, 0.01846575774417754, 'Arizona'),
#   Text(1.0996227955943063, 0.028804642149534924, 'Arkansas'),
#   Text(1.090846190990774, 0.1416142210405427, 'California'),
#   Text(1.0690227289984446, 0.2592111202952493, 'Colorado'),
#   Text(1.0665612274179355, 0.26916007907701917, 'Delaware'),
#   Text(1.0601384683179396, 0.2934389680879031, 'District of Columbia'),
#   Text(1.0471760755942148, 0.3367822244464506, 'Florida'),
#   Text(1.0318357857282534, 0.3812019298095932, 'Georgia'),
#   Text(1.0224901499243133, 0.40560312290187733, 'Guam'),
#   Text(1.0218077892998974, 0.4073190907949893, 'Hawaii'),
#   Text(1.020537831779297, 0.41049060148462757, 'Idaho'),
#   Text(-1.0761373915779193, 0.2278778498403744, 'Illinois'),
#   Text(0.7789103683247989, -0.7767230124800774, 'Indiana'),
#   Text(0.8083132100611107, -0.74607623902702, 'Iowa'),
#   Text(0.8272686024342352, -0.7250011444311708, 'Kansas'),
#   Text(0.8435451358356439, -0.7059968865427277, 'Kentucky'),
#   Text(0.8627751050804113, -0.682362893227266, 'Louisiana'),
#   Text(0.8809562236600628, -0.6587231072268542, 'Maryland'),
#   Text(0.9057279209538653, -0.6242250661456882, 'Michigan'),
#   Text(0.9282092261954152, -0.5902775892795766, 'Minnesota'),
#   Text(0.9381803281892067, -0.5742975463980258, 'Mississippi'),
#   Text(0.9505824365248895, -0.5535278054175821, 'Missouri'),
#   Text(0.9623012441279059, -0.5328942817763057, 'Montana'),
#   Text(0.9643516789322671, -0.5291746775314534, 'Nebraska'),
#   Text(0.9669165134655759, -0.5244735036086903, 'Nevada'),
#   Text(0.9686282610351356, -0.5213053730051604, 'New Mexico'),
#   Text(1.0071505131154437, -0.4423209738767751, 'New York'),
#   Text(1.0413749766879004, -0.3543136434407731, 'North Carolina'),
#   Text(1.0442252849013203, -0.34582301018404865, 'North Dakota'),
#   Text(1.0444572743195686, -0.34512172073188563, 'Northern Mariana Islands'),
#   Text(1.0556879151768608, -0.30906799534978324, 'Ohio'),
#   Text(1.0666741307443992, -0.2687122974496708, 'Oklahoma'),
#   Text(1.06887026935134, -0.259839079618124, 'Oregon'),
#   Text(1.0745829207979916, -0.23509901388405968, 'Pennsylvania'),
#   Text(1.0793507580992268, -0.2121366092654091, 'South Carolina'),
#   Text(1.0803186140563763, -0.20715137490084584, 'South Dakota'),
#   Text(1.0822017761107545, -0.19707692859066092, 'Tennessee'),
#   Text(1.0880316487226014, -0.16182438437385738, 'Texas'),
#   Text(1.0921182936562166, -0.13144440901549917, 'Utah'),
#   Text(1.095762831871873, -0.09645629211271683, 'Virginia'),
#   Text(1.098741198280608, -0.05260968732937079, 'Washington'),
#   Text(1.099354988321807, -0.037664434841902086, 'West Virginia'),
#   Text(1.099854158688337, -0.017911717281445062, 'Wisconsin'),
#   Text(1.0999998101852781, -0.0006462138596617117, 'Wyoming')])

# %%
dfNoIllinois = df[df["state_name"] != 'Illinois']
dfNoIllinois
# Out:
#       index    zip       city state_id state_name           county_name  Total
# 0      2583  10001   New York       NY   New York              New York   37.0
# 1      2584  10002   New York       NY   New York              New York   90.0
# 2      2585  10003   New York       NY   New York              New York   42.0
# 3      2586  10004   New York       NY   New York              New York   26.0
# 4      2587  10005   New York       NY   New York              New York   27.0
# ...     ...    ...        ...      ...        ...                   ...    ...
# 4336  33658  99669   Soldotna       AK     Alaska       Kenai Peninsula    1.0
# 4337  33690  99709  Fairbanks       AK     Alaska  Fairbanks North Star    1.0
# 4338  33691  99712  Fairbanks       AK     Alaska  Fairbanks North Star    2.0
# 4339  33760  99801     Juneau       AK     Alaska                Juneau    2.0
# 4340  33785  99929   Wrangell       AK     Alaska              Wrangell    1.0
#
# [3343 rows x 7 columns]

# %%
ax1 = plt.scatter(dfNoIllinois["zip"], dfNoIllinois["Total"])

# %%
states = dfNoIllinois['state_name']
df2 = dfNoIllinois.groupby('state_name')['Total'].sum()
df2= pd.DataFrame(df2)



states = states.T.drop_duplicates().T
states = pd.DataFrame(states)
states = states.sort_values('state_name')
plt.pie(df2['Total'], labels = states['state_name'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe471b91490>,
#   <matplotlib.patches.Wedge at 0x7fe471b91950>,
#   <matplotlib.patches.Wedge at 0x7fe471b91910>,
#   <matplotlib.patches.Wedge at 0x7fe471b9c050>,
#   <matplotlib.patches.Wedge at 0x7fe471b9ce50>,
#   <matplotlib.patches.Wedge at 0x7fe471b28410>,
#   <matplotlib.patches.Wedge at 0x7fe471b28250>,
#   <matplotlib.patches.Wedge at 0x7fe471b288d0>,
#   <matplotlib.patches.Wedge at 0x7fe471b9c610>,
#   <matplotlib.patches.Wedge at 0x7fe471b28290>,
#   <matplotlib.patches.Wedge at 0x7fe471b91450>,
#   <matplotlib.patches.Wedge at 0x7fe471b403d0>,
#   <matplotlib.patches.Wedge at 0x7fe471b40490>,
#   <matplotlib.patches.Wedge at 0x7fe471b40a50>,
#   <matplotlib.patches.Wedge at 0x7fe471b4b050>,
#   <matplotlib.patches.Wedge at 0x7fe471b4b610>,
#   <matplotlib.patches.Wedge at 0x7fe471b55110>,
#   <matplotlib.patches.Wedge at 0x7fe471b551d0>,
#   <matplotlib.patches.Wedge at 0x7fe471b55790>,
#   <matplotlib.patches.Wedge at 0x7fe471b65290>,
#   <matplotlib.patches.Wedge at 0x7fe471b65350>,
#   <matplotlib.patches.Wedge at 0x7fe471b65910>,
#   <matplotlib.patches.Wedge at 0x7fe471aef410>,
#   <matplotlib.patches.Wedge at 0x7fe471aef4d0>,
#   <matplotlib.patches.Wedge at 0x7fe471aefa90>,
#   <matplotlib.patches.Wedge at 0x7fe471afb090>,
#   <matplotlib.patches.Wedge at 0x7fe471afb650>,
#   <matplotlib.patches.Wedge at 0x7fe471b60150>,
#   <matplotlib.patches.Wedge at 0x7fe471b60210>,
#   <matplotlib.patches.Wedge at 0x7fe471b607d0>,
#   <matplotlib.patches.Wedge at 0x7fe471b112d0>,
#   <matplotlib.patches.Wedge at 0x7fe471b11390>,
#   <matplotlib.patches.Wedge at 0x7fe471b11950>,
#   <matplotlib.patches.Wedge at 0x7fe471b1d450>,
#   <matplotlib.patches.Wedge at 0x7fe471b1d510>,
#   <matplotlib.patches.Wedge at 0x7fe471b1dad0>,
#   <matplotlib.patches.Wedge at 0x7fe471aa80d0>,
#   <matplotlib.patches.Wedge at 0x7fe471aa8690>,
#   <matplotlib.patches.Wedge at 0x7fe471ab1190>,
#   <matplotlib.patches.Wedge at 0x7fe471ab1250>,
#   <matplotlib.patches.Wedge at 0x7fe471ab1810>,
#   <matplotlib.patches.Wedge at 0x7fe471abe310>,
#   <matplotlib.patches.Wedge at 0x7fe471abe3d0>,
#   <matplotlib.patches.Wedge at 0x7fe471abe990>,
#   <matplotlib.patches.Wedge at 0x7fe471acc490>],
#  [Text(1.0997167468467253, 0.024961504458986233, 'Alabama'),
#   Text(1.0986584381398348, 0.05431055426101946, 'Alaska'),
#   Text(1.0956466222148438, 0.0977674753136432, 'Arizona'),
#   Text(1.0894156421603003, 0.15222863927809574, 'Arkansas'),
#   Text(0.8522876628165077, 0.6954176729209397, 'California'),
#   Text(0.33526005629244127, 1.0476643998221897, 'Colorado'),
#   Text(0.2831245959845865, 1.0629395388019796, 'Delaware'),
#   Text(0.15271337184330774, 1.0893477984832245, 'District of Columbia'),
#   Text(-0.08654901075339232, 1.0965898361454975, 'Florida'),
#   Text(-0.3305948397296395, 1.0491458678106367, 'Georgia'),
#   Text(-0.4597476643018738, 0.9993158085254991, 'Guam'),
#   Text(-0.4686229468724635, 0.9951846731459284, 'Hawaii'),
#   Text(-0.484943847629532, 0.9873345251971418, 'Idaho'),
#   Text(-0.5807880402739951, 0.9341762426195029, 'Indiana'),
#   Text(-0.7585499946505002, 0.7966190467317024, 'Iowa'),
#   Text(-0.8599710362117923, 0.6858934442585207, 'Kansas'),
#   Text(-0.9362378599969776, 0.577458803299664, 'Kentucky'),
#   Text(-1.0106542293047935, 0.43425571819877523, 'Louisiana'),
#   Text(-1.0624339033870684, 0.28501614153187477, 'Maryland'),
#   Text(-1.0981881877491573, 0.06310867046786511, 'Michigan'),
#   Text(-1.0894156420907073, -0.15222863977613502, 'Minnesota'),
#   Text(-1.0711302165986036, -0.2503598591815958, 'Mississippi'),
#   Text(-1.0347365159081174, -0.3732564033560986, 'Missouri'),
#   Text(-0.9853844801066373, -0.48889408501737114, 'Montana'),
#   Text(-0.9751714319835205, -0.5089603896603451, 'Nebraska'),
#   Text(-0.9617123034160275, -0.5339564078258063, 'Nevada'),
#   Text(-0.9523014533008415, -0.5505651115364154, 'New Mexico'),
#   Text(-0.6418025975952003, -0.8933585090656794, 'New York'),
#   Text(-0.18367089183595411, -1.0845575150687885, 'North Carolina'),
#   Text(-0.13670103015525562, -1.0914727794839834, 'North Dakota'),
#   Text(-0.13281466191809263, -1.0919525015217388, 'Northern Mariana Islands'),
#   Text(0.0670176325460035, -1.0979565733342684, 'Ohio'),
#   Text(0.2854888357004402, -1.062306982322157, 'Oklahoma'),
#   Text(0.33199505403044627, -1.0487036207143186, 'Oregon'),
#   Text(0.4575230779111725, -1.0003362600539318, 'Pennsylvania'),
#   Text(0.5674273443586407, -0.9423514253579185, 'South Carolina'),
#   Text(0.5903183734503117, -0.9281832889936009, 'South Dakota'),
#   Text(0.6354258282374785, -0.8979053495824127, 'Tennessee'),
#   Text(0.7798913524473113, -0.7757380217431036, 'Texas'),
#   Text(0.8855832094610089, -0.6524893708871733, 'Utah'),
#   Text(0.9829796127506194, -0.4937115361389102, 'Virginia'),
#   Text(1.0648056226127192, -0.2760235244546012, 'Washington'),
#   Text(1.0819207560638031, -0.19861389074868088, 'West Virginia'),
#   Text(1.0959037438814634, -0.09484189025210259, 'Wisconsin'),
#   Text(1.0999946634813014, -0.003426413964883393, 'Wyoming')])
